# %% [markdown]
# ###NOAA Forecast Scraper
#
# Required Input:
# Latitude and Longitude of the forecast point.  This should be in decimal format.  Northern latitudes and Eastern Longitudes have positive values, Sorthern latitudes and Wastern Longitudes have negative values.
#
# The input latitude and longitudes should be a list of 2 component lists: forecastLocations = [[Lat_1, Long_1], [Lat_2,Long_2]... [Lat_n, Long_n]]
#
# ex: For forcasts in Seattle, WA and Sydney Australia: forecastLocations = [[47.61, -122.34], [-33.85, 151.21]].  The actual numerical values of the latitude and longitude can contain up to , however NOAA makes forecasts for 2.5km boxes, so precision beyond 0.01 degrees is unnecessary except at the rotational poles, which is beyond the scope of this project.
#
# Objectives:
# - Download forecasts for the next 24 hour period e.g. starting at 00 hours tomorrow and continuing through hour 23
# - Run quickly (less than 5 minutes)
# - Have the capacity to run at anytime in the day prior to the forecast day
# - Record date and time it was run in output files
#
# Expected Output:
# - csv files which include all available data coded by which powerplant they should be applied to.
# - these files should
#
# Tips:
# - include time delays in the script so we don't get locked out
#
# Tasks
# - create a list of urls to be scraped ***(DONE)***
# - create a scraper which outputs wanted data from each url
# - save scraper output in usable format for later processing

# %%
#Imports
import pandas as pd

import datetime
from time import gmtime, strftime
from bs4 import BeautifulSoup as BSoup
from urllib2 import urlopen
from time import sleep #Use this to space out requests so I don't get locked out

# %% [markdown]
# ###Dictionary of urls to be scraped with the name of the associated powerplat as key
#
# The objective of this section is to create a dictionary of urls which can be used to access the NOAA digital forecasted weather

# %%
#Creates globally accessible DataFrame with Name, Latitude and Longitude 
#of Wind Farms in Wind_CapLoc.csv 

dfWind = pd.read_csv('Wind_CapLoc.csv')
dfLatLong = dfWind[['Name','Lat','Long']]

# %%
#Creates a list of latitudes and longitudes of wind farms ordered by their order in dfWind
LatList = []
LongList = []

for Lat in dfLatLong.Lat:
    LatList.append(round(Lat,2))
for Long in dfLatLong.Long:
    LongList.append(round(Long,2))

# %%
#Create dictionary for direction strings and direction degrees
DirKeys = ['N', 'NNE', 'NE', 'ENE', 'E', 'ESE', 'SE', 'SSE', 'S', 'SSW', 'SW', 'WSW', 'W', 'WNW', 'NW', 'NNW']
DirVals = [0.0, 22.5, 45.0, 67.5, 90.0, 112.5,135.0, 157.5, 180.0, 202.5, 225.0, 247.5, 270.0, 292.5, 315.0, 337.5]

DirDict = dict(zip(DirKeys,DirVals))

# %%
#Unique day stamp for the forecast day.  This returns the number of days since Jan 1 1970 that the forecast
#day is: 10/2/15 = 16710

def forecast_day():
    epoch = datetime.datetime.utcfromtimestamp(0)
    today = datetime.datetime.today()
    epochtime = today - epoch
    return epochtime.days + 1 #incremented because forecast is for tomorrow.

# %%
forecast_day()
# Out:
# 16744

# %%
def make_NOAA_urls(LatList, LongList):
    lurl = []
    iHour = datetime.datetime.today().hour
    iAheadHour = 24 - iHour + 3 # Training +3 b/c pacific time is 3 hours behind Eastern
    
    for i in range(len(LatList)):
        lurl.append('http://forecast.weather.gov/MapClick.php?&AheadHour=' + str(iAheadHour) + 
               '&FcstType=digital&textField1=' + str(LatList[i]) + '&textField2=' + 
                str(LongList[i]))
        
    return lurl

# %%
urls = make_NOAA_urls(LatList, LongList)

# %%
print urls
# Out:
# ['http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=40.9&textField2=-121.8', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=38.14&textField2=-121.81', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=38.12&textField2=-121.85', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=38.17&textField2=-121.85', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=38.12&textField2=-121.77', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=38.17&textField2=-121.85', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=38.12&textField2=-121.77', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=38.14&textField2=-121.86', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=38.12&textField2=-121.82', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=38.16&textField2=-121.8', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.75&textField2=-121.6', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.73&textField2=-121.65', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.73&textField2=-121.65', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.73&textField2=-121.65', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.73&textField2=-121.65', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.73&textField2=-121.65', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.81&textField2=-121.67', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.7&textField2=-121.61', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.76&textField2=-121.61', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.74&textField2=-121.65', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.73&textField2=-121.65', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.74&textField2=-121.43', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.73&textField2=-121.65', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.04&textField2=-121.18', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=35.31&textField2=-118.43', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=35.35&textField2=-118.19', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.73&textField2=-121.65', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=37.73&textField2=-121.65', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=35.26&textField2=-118.25', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=35.07&textField2=-118.27', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=34.93&textField2=-118.46', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=35.02&textField2=-118.32', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=35.01&textField2=-118.24', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=35.03&textField2=-118.23', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=35.01&textField2=-118.24', 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=35.03&textField2=-118.35', 'http:// ...

# %%
html = urlopen(urls[0]).read() #This pings the NOAA server, use sparingly
soup = BSoup(html)
print soup.prettify()
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
# <html>
#  <head>
#   <title>
#    Tabular Weather Forecast for 40.89N 121.8W (Elev. 5000 ft)
#   </title>
#   <link href="fonts/main.css" rel="STYLESHEET" type="text/css"/>
#  </head>
#  <body background="#FFFFFF" leftmargin="0" marginheight="0" marginwidth="0" rightmargin="0" topmargin="0">
#   <table background="/images/wtf/topbanner.jpg" border="0" cellpadding="0" cellspacing="0" width="100%">
#    <tr>
#     <td align="right" height="19">
#      <a href="#contents">
#       <img alt="Skip Navigation Links" border="0" height="1" src="/images/wtf/skipgraphic.gif" width="1"/>
#      </a>
#      <a href="http://weather.gov">
#       <span class="nwslink">
#        weather.gov
#       </span>
#      </a>
#     </td>
#    </tr>
#   </table>
#   <table border="0" cellpadding="0" cellspacing="0" width="100%">
#    <tr>
#     <td rowspan="2">
#      <a href="http://www.noaa.gov">
#       <img alt="NOAA logo - Click to go to the NOAA homepage" border="0" height="78" src="/images/wtf/noaaleft.jpg" title="NOAA logo - Click to go to the NOAA homepage" width="85"/>
#      </a>
#     </td>
#     <td align="left">
#      <img alt="National Weather Service Forecast Office" border="0" height="20" src="/images/wtf/nwsfo.jpg" title="National Weather Service Forecast Office"/>
#     </td>
#     <td background="/images/wtf/wfo_bkgrnd.jpg" rowspan="2" width="100%">
#     </td>
#     <td align="right" rowspan="2">
#      <a href="http://weather.gov">
#       <img alt="NWS logo - Click to go to the NWS homepage" border="0" height="78" src="/images/wtf/nwsright.jpg" title="NWS logo - Click to go to the NWS homepage" width="85"/>
#      </a>
#     </td>
#    </tr>
#    <tr>
#     <td>
#      <img alt="Sacramento, CA" border="0" height="58" src="/images/wtf/banner_STO.jpg" title="Sacramento, CA"/>
#     </td>
#    </tr>
#   </table>
#   <table background="/images/wtf/navbkgrnd.gif" border="0" cellpadding="0" cellspacing="0" width="100%">
#    <tr>
#     <td align="left" width="94">
#      <img alt="" border="0" height="23" src="/images/wtf/navbarleft.jpg" width="94"/>
#     </td>
#     <td align="center" class="nav" id="menuitem" width="13%">
#      <a href="http://www.wrh.noaa.gov/sto">
#       Home
#      </a>
#     </td>
#     <td align="right" class="nav" id="menuitem" width="13%">
#      <a href="http://www.weather.gov/pa/">
#       News
#      </a>
#     </td>
#     <td align="right" class="nav" id="menuitem" width="23%">
#      <a href="http://www.weather.gov/organization.php">
#       Organization
#      </a>
#     </td>
#     <td align="right" class="yellow" width="10%">
#     </td>
#     <td align="left" class="searchinput" nowrap="" width="20%">
#      <form action="http://search.usa.gov/search" id="query" method="get" style="margin-bottom:0; margin-top:0;">
#       <input name="v:project" type="hidden" value="firstgov"/>
#       <label class="yellow" for="query" span="">
#        Search for:
#        <input id="Search" name="query" size="10" type="text"/>
#       </label>
#       <input checked="checked" id="nws" name="affiliate" type="radio" value="nws.noaa.gov"/>
#       <label class="white" for="nws" span="">
#        NWS
#       </label>
#       <input id="noaa" name="affiliate" type="radio" value="noaa.gov"/>
#       <label class="white" for="noaa" span="">
#        All NOAA
#       </label>
#       <input type="submit" value="Go"/>
#      </form>
#     </td>
#     <td width="2%">
#     </td>
#     <td align="right">
#      <img alt="" border="0" height="23" src="/images/wtf/navbarendcap.jpg" width="24"/>
#     </td>
#    </tr>
#   </table>
#   <table align="center" border="0" width="800">
#    <tr>
#     <td width="60%">
#      <b>
#       Point Forecast:
#      </b>
#      7 Miles W Burney CA
#      <br/>
#      40.89N 121.8W  (Elev. 5000 ft)
#      <br/>
#     </td>
#     <td align="right" width="40%">
#      Last Update: 2:31 am PST Nov 4, 2015
#     </td>
#    </tr>
#    <tr>
#     <td colspan="2">
#      <img alt="Tabular Forecast" src="/images/wtf/DigBanner.jpg" title="Tabular Forecast"/>
#     </td>
#    </tr>
#   </table>
#   <table align="center" border="0" cellpadding="0" cellspacing="0" width="800">
#    <tr>
#     <td align="right" colspan="2" href="http://forecast.weather.gov/MapClick.php?&amp;AheadHour=12&amp;FcstType=digital&amp;textField1=40.9&amp;textField2=-121.8&amp;menu=1" valign="bottom">
#      [hide menu]  |
#      <b>
#       Font Size:
#      </b>
#      <font size="3">
#       <a href="http://forecast.weather.gov/MapClick.php?&amp;AheadHour=12&amp;FcstType=digital&amp;textField1=40.9&amp;textField2=-121.8&amp;fs=3">
#        <b>
#         A
#        </b>
#       </a>
#      </font>
#      <font size="2">
#       <a href="http://forecast.weather.gov/MapClick.php?&amp;AheadHour=12&amp;FcstType=digital&amp;textField1=40.9&amp;textField2=-121.8&amp;fs=2">
#        <b>
#         A
#        </b>
#       </a>
#      </font>
#      <font size="1">
#       <a href="http://forecast.weather.gov/MapClick.php?&amp;AheadHour=12&amp;FcstType=digital&amp;textField1=40.9&amp;textField2=-121.8&amp;fs=1">
#        <b>
#         A
#        </b>
#       </a>
#      </font>
#      <a href="http://forecast.weather.gov/MapClick.php?lat=40.9&amp;lon=-121.8&amp;FcstType=digitalDWML">
#       <img alt="Get as XML" src="/images/wtf/xml-small.gif" title="Get as XML"/>
#      </a>
#     </td>
#    </tr>
#    <form action="MapClick.php" method="get" name="form1">
#     <tr>
#      <td align="left" bgcolor="#CCCCCC" valign="top" width="100%">
#       <table align="left" border="1" cellpadding="1" cellspacing="1" valign="top" width="100%">
#        <tr>
#         <td bgcolor="#999999" colspan="1" valign="top">
#          <b>
#           Weather Elements
#          </b>
#         </td>
#         <td bgcolor="#999999" valign="top">
#          <b>
#           Weather/Precipitation
#          </b>
#         </td>
#         <td bgcolor="#999999" valign="top">
#          <b>
#           Fire Weather
#          </b>
#         </td>
#        </tr>
#        <tr>
#         <td align="left" valign="top" width="33%">
#          <input checked="" name="w0" type="checkBOX" value="t"/>
#          <b>
#           Temperature (°F)
#          </b>
#          <br/>
#          <input checked="" name="w1" type="checkBOX" value="td"/>
#          <b>
#           Dewpoint (°F)
#          </b>
#          <br/>
#          <input checked="" name="w2" type="checkBOX" value="wc"/>
#          <b>
#           Wind Chill (°F)
#          </b>
#          <br/>
#          <hr/>
#          <input checked="" name="w3" type="checkBOX" value="sfcwind"/>
#          <b>
#           Surface Wind
#          </b>
#          <select name="w3u">
#           <option value="0">
#            kt
#           </option>
#           <option selected="" value="1">
#            mph
#           </option>
#           <option value="2">
#            km/h
#           </option>
#           <option value="3">
#            m/s
#           </option>
#          </select>
#          <br/>
#          <input checked="" name="w4" type="checkBOX" value="sky"/>
#          <b>
#           Sky Cover (%)
#          </b>
#          <br/>
#          <input checked="" name="w5" type="checkBOX" value="pop"/>
#          <b>
#           Precipitation Potential (%)
#          </b>
#          <br/>
#          <input checked="" name="w6" type="checkBOX" value="rh"/>
#          <b>
#           Relative Humidity (%)
#          </b>
#          <br/>
#         </td>
#         <td align="left" valign="top" width="33%">
#          <input checked="" name="w7" type="checkBOX" value="rain"/>
#          <b>
#           Rain
#          </b>
#          <br/>
#          <input checked="" name="w8" type="checkBOX" value="thunder"/>
#          <b>
#           Thunder
#          </b>
#          <br/>
#          <input checked="" name="w9" type="checkBOX" value="snow"/>
#          <b>
#           Snow
#          </b>
#          <br/>
#          <input checked="" name="w10" type="checkBOX" value="fzg"/>
#          <b>
#           Freezing Rain
#          </b>
#          <br/>
#          <input checked="" name="w11" type="checkBOX" value="sleet"/>
#          <b>
#           Sleet
#          </b>
#          <br/>
#          <input name="w12" type="checkbox" value="fog"/>
#          <b>
#           Fog
#          </b>
#          <br/>
#         </td>
#         <td align="left" valign="top" width="33%">
#          <input name="w13" type="checkbox" value="mhgt"/>
#          <b>
#           Mixing Height
#          </b>
#          <select name="w13u">
#           <option selected="" value="0">
#            x100ft
#           </option>
#           <option value="1">
#            x100m
#           </option>
#          </select>
#          <br/>
#          <input name="w14" type="checkbox" value="lal"/>
#          <b>
#           Lightning Activity Level
#          </b>
#          <br/>
#          <input name="w15" type="checkbox" value="twind"/>
#          <b>
#           Trans. Wind
#          </b>
#          <select name="w15u">
#           <option value="0">
#            kt
#           </option>
#           <option selected="" value="1">
#            mph
#           </option>
#           <option value="2">
#            km/h
#           </option>
#           <option value="3">
#            m/s
#           </option>
#          </select>
#          <br/>
#         </td>
#        </tr>
#       </table>
#      </td>
#     </tr>
#     <tr>
#      <td align="center" bgcolor="#CCCCCC" valign="top" width="100%">
#       <br/>
#       <table align="center" border="0" cellpadding="0" cellspacing="0" valign="top" width="100%">
#        <tr>
#         <td align="left" valign="top">
#          <b>
#           48-Hour Period Starting:
#          </b>
#          <select name="AheadHour">
#           <option value="0">
#            12pm Wed, Nov 4 2015
#           </option>
#           <option value="1">
#            1pm Wed, Nov 4 2015
#           </option>
#           <option value="2">
#            2pm Wed, Nov 4 2015
#           </option>
#           <option value="3">
#            3pm Wed, Nov 4 2015
#           </option>
#           <option value="4">
#            4pm Wed, Nov 4 2015
#           </option>
#           <option value="5">
#            5pm Wed, Nov 4 2015
#           </option>
#           <option value="6">
#            6pm Wed, Nov 4 2015
#           </option>
#           <option value="7">
#            7pm Wed, Nov 4 2015
#           </option>
#           <option value="8">
#            8pm Wed, Nov 4 2015
#           </option>
#           <option value="9">
#            9pm Wed, Nov 4 2015
#           </option>
#           <option value="10">
#            10pm Wed, Nov 4 2015
#           </option>
#           <option value="11">
#            11pm Wed, Nov 4 2015
#           </option>
#           <option selected="" value="12">
#            <b>
#             12am Thu, Nov 5 2015
#            </b>
#           </option>
#           <option value="13">
#            1am Thu, Nov 5 2015
#           </option>
#           <option value="14">
#            2am Thu, Nov 5 2015
#           </option>
#           <option value="15">
#            3am Thu, Nov 5 2015
#           </option>
#           <option value="16">
#            4am Thu, Nov 5 2015
#           </option>
#           <option value="17">
#            5am Thu, Nov 5 2015
#           </option>
#           <option value="18">
#            6am Thu, Nov 5 2015
#           </option>
#           <option value="19">
#            7am Thu, Nov 5 2015
#           </option>
#           <option value="20">
#            8am Thu, Nov 5 2015
#           </option>
#           <option value="21">
#            9am Thu, Nov 5 2015
#           </option>
#           <option value="22">
#            10am Thu, Nov 5 2015
#           </option>
#           <option value="23">
#            11am Thu, Nov 5 2015
#           </option>
#           <option value="24">
#            12pm Thu, Nov 5 2015
#           </option>
#           <option value="25">
#            1pm Thu, Nov 5 2015
#           </option>
#           <option value="26">
#            2pm Thu, Nov 5 2015
#           </option>
#           <option value="27">
#            3pm Thu, Nov 5 2015
#           </option>
#           <option value="28">
#            4pm Thu, Nov 5 2015
#           </option>
#           <option value="29">
#            5pm Thu, Nov 5 2015
#           </option>
#           <option value="30">
#            6pm Thu, Nov 5 2015
#           </option>
#           <option value="31">
#            7pm Thu, Nov 5 2015
#           </option>
#           <option value="32">
#            8pm Thu, Nov 5 2015
#           </option>
#           <option value="33">
#            9pm Thu, Nov 5 2015
#           </option>
#           <option value="34">
#            10pm Thu, Nov 5 2015
#           </option>
#           <option value="35">
#            11pm Thu, Nov 5 2015
#           </option>
#           <option value="36">
#            12am Fri, Nov 6 2015
#           </option>
#           <option value="37">
#            1am Fri, Nov 6 2015
#           </option>
#           <option value="38">
#            2am Fri, Nov 6 2015
#           </option>
#           <option value="39">
#            3am Fri, Nov 6 2015
#           </option>
#           <option value="40">
#            4am Fri, Nov 6 2015
#           </option>
#           <option value="41">
#            5am Fri, Nov 6 2015
#           </option>
#           <option value="42">
#            6am Fri, Nov 6 2015
#           </option>
#           <option value="43">
#            7am Fri, Nov 6 2015
#           </option>
#           <option value="44">
#            8am Fri, Nov 6 2015
#           </option>
#           <option value="45">
#            9am Fri, Nov 6 2015
#           </option>
#           <option value="46">
#            10am Fri, Nov 6 2015
#           </option>
#           <option value="47">
#            11am Fri, Nov 6 2015
#           </option>
#           <option value="48">
#            12pm Fri, Nov 6 2015
#           </option>
#           <option value="49">
#            1pm Fri, Nov 6 2015
#           </option>
#           <option value="50">
#            2pm Fri, Nov 6 2015
#           </option>
#           <option value="51">
#            3pm Fri, Nov 6 2015
#           </option>
#           <option value="52">
#            4pm Fri, Nov 6 2015
#           </option>
#           <option value="53">
#            5pm Fri, Nov 6 2015
#           </option>
#           <option value="54">
#            6pm Fri, Nov 6 2015
#           </option>
#           <option value="55">
#            7pm Fri, Nov 6 2015
#           </option>
#           <option value="56">
#            8pm Fri, Nov 6 2015
#           </option>
#           <option value="57">
#            9pm Fri, Nov 6 2015
#           </option>
#           <option value="58">
#            10pm Fri, Nov 6 2015
#           </option>
#           <option value="59">
#            11pm Fri, Nov 6 2015
#           </option>
#           <option value="60">
#            12am Sat, Nov 7 2015
#           </option>
#           <option value="61">
#            1am Sat, Nov 7 2015
#           </option>
#           <option value="62">
#            2am Sat, Nov 7 2015
#           </option>
#           <option value="63">
#            3am Sat, Nov 7 2015
#           </option>
#           <option value="64">
#            4am Sat, Nov 7 2015
#           </option>
#           <option value="65">
#            5am Sat, Nov 7 2015
#           </option>
#           <option value="66">
#            6am Sat, Nov 7 2015
#           </option>
#           <option value="67">
#            7am Sat, Nov 7 2015
#           </option>
#           <option value="68">
#            8am Sat, Nov 7 2015
#           </option>
#           <option value="69">
#            9am Sat, Nov 7 2015
#           </option>
#           <option value="70">
#            10am Sat, Nov 7 2015
#           </option>
#           <option value="71">
#            11am Sat, Nov 7 2015
#           </option>
#           <option value="72">
#            12pm Sat, Nov 7 2015
#           </option>
#           <option value="73">
#            1pm Sat, Nov 7 2015
#           </option>
#           <option value="74">
#            2pm Sat, Nov 7 2015
#           </option>
#           <option value="75">
#            3pm Sat, Nov 7 2015
#           </option>
#           <option value="76">
#            4pm Sat, Nov 7 2015
#           </option>
#           <option value="77">
#            5pm Sat, Nov 7 2015
#           </option>
#           <option value="78">
#            6pm Sat, Nov 7 2015
#           </option>
#           <option value="79">
#            7pm Sat, Nov 7 2015
#           </option>
#           <option value="80">
#            8pm Sat, Nov 7 2015
#           </option>
#           <option value="81">
#            9pm Sat, Nov 7 2015
#           </option>
#           <option value="82">
#            10pm Sat, Nov 7 2015
#           </option>
#           <option value="83">
#            11pm Sat, Nov 7 2015
#           </option>
#           <option value="84">
#            12am Sun, Nov 8 2015
#           </option>
#           <option value="85">
#            1am Sun, Nov 8 2015
#           </option>
#           <option value="86">
#            2am Sun, Nov 8 2015
#           </option>
#           <option value="87">
#            3am Sun, Nov 8 2015
#           </option>
#           <option value="88">
#            4am Sun, Nov 8 2015
#           </option>
#           <option value="89">
#            5am Sun, Nov 8 2015
#           </option>
#           <option value="90">
#            6am Sun, Nov 8 2015
#           </option>
#           <option value="91">
#            7am Sun, Nov 8 2015
#           </option>
#           <option value="92">
#            8am Sun, Nov 8 2015
#           </option>
#           <option value="93">
#            9am Sun, Nov 8 2015
#           </option>
#           <option value="94">
#            10am Sun, Nov 8 2015
#           </option>
#           <option value="95">
#            11am Sun, Nov 8 2015
#           </option>
#           <option value="96">
#            12pm Sun, Nov 8 2015
#           </option>
#           <option value="97">
#            1pm Sun, Nov 8 2015
#           </option>
#           <option value="98">
#            2pm Sun, Nov 8 2015
#           </option>
#           <option value="99">
#            3pm Sun, Nov 8 2015
#           </option>
#           <option value="100">
#            4pm Sun, Nov 8 2015
#           </option>
#           <option value="101">
#            5pm Sun, Nov 8 2015
#           </option>
#           <option value="102">
#            6pm Sun, Nov 8 2015
#           </option>
#           <option value="103">
#            7pm Sun, Nov 8 2015
#           </option>
#           <option value="104">
#            8pm Sun, Nov 8 2015
#           </option>
#           <option value="105">
#            9pm Sun, Nov 8 2015
#           </option>
#           <option value="106">
#            10pm Sun, Nov 8 2015
#           </option>
#           <option value="107">
#            11pm Sun, Nov 8 2015
#           </option>
#          </select>
#          <input name="Submit" type="submit" value="Submit"/>
#          <input name="FcstType" type="hidden" value="digital"/>
#          <input name="textField1" type="hidden" value="40.9"/>
#          <input name="textField2" type="hidden" value="-121.8"/>
#          <input name="site" type="hidden" value="all"/>
#          <input name="unit" type="hidden" value="0"/>
#          <input name="dd" type="hidden" value=""/>
#          <input name="bw" type="hidden" value=""/>
#         </td>
#         <td align="right" valign="top">
#          <img alt="Forward 2 Days" src="/images/wtf/2dayback-grey.gif" title="Back 2 Days"/>
#          <input alt="Forward 2 Days" name="AheadDay" src="/images/wtf/2dayahead.gif" title="Forward 2 Days" type="image" value="60"/>
#         </td>
#        </tr>
#       </table>
#      </td>
#     </tr>
#    </form>
#   </table>
#   <table align="center" border="0" width="800">
#    <tr>
#     <td colspan="25">
#      <hr/>
#     </td>
#    </tr>
#    <tr align="center">
#     <td align="left" width="5%">
#      <font size="1">
#       <b>
#        Date
#       </b>
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#       <b>
#        11/05
#       </b>
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#     <td class="date" width="3%">
#      <font size="1">
#      </font>
#     </td>
#    </tr>
#    <tr align="center">
#     <td align="left" class="date">
#      <font size="1">
#       <b>
#        Hour (PST)
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        00
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        01
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        02
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        03
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        04
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        05
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        06
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        07
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        08
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        09
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        10
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        11
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        12
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        13
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        14
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        15
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        16
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        17
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        18
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        19
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        20
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        21
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        22
#       </b>
#      </font>
#     </td>
#     <td class="date">
#      <font size="1">
#       <b>
#        23
#       </b>
#      </font>
#     </td>
#    </tr>
#    <tr align="center">
#     <td align="left" width="5%">
#      <font color="#FF0000" size="1">
#       Temperature (°F)
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        33
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        33
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        33
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        33
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        32
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        32
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        32
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        33
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        35
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        38
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        41
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        43
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        45
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        45
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        46
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        46
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        45
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        44
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        42
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        40
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        38
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        37
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        36
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        36
#       </b>
#      </font>
#     </td>
#    </tr>
#    <tr align="center">
#     <td align="left" width="5%">
#      <font color="#009900" size="1">
#       Dewpoint (°F)
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        23
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        23
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        24
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        24
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        24
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        24
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        24
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        25
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        25
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        25
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        25
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        24
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        24
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        22
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        22
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        23
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        24
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        27
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        29
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        30
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        30
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        30
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        30
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#009900" size="1">
#       <b>
#        30
#       </b>
#      </font>
#     </td>
#    </tr>
#    <tr align="center">
#     <td align="left" width="5%">
#      <font color="#0000CC" size="1">
#       Wind Chill (°F)
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#    </tr>
#    <tr align="center">
#     <td align="left" width="5%">
#      <font color="#990099" size="1">
#       Surface Wind (mph)
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        7
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        6
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        6
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        6
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        1
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        1
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        1
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        1
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        1
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        1
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        2
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        2
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        2
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        2
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        2
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        2
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        3
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        3
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        3
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        3
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        3
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        3
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        3
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#990099" size="1">
#       <b>
#        3
#       </b>
#      </font>
#     </td>
#    </tr>
#    <tr align="center">
#     <td align="left" width="5%">
#      <font color="#666666" size="1">
#       Wind Dir
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        E
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        E
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        E
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        E
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        S
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        S
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        S
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        NNE
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        NNE
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        NNE
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        WSW
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        WSW
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        WSW
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        WSW
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        WSW
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        WSW
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        NNE
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        NNE
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        NNE
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        NNE
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        NNE
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        NNE
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        ENE
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#666666" size="1">
#       <b>
#        ENE
#       </b>
#      </font>
#     </td>
#    </tr>
#    <tr align="center">
#     <td align="left" width="5%">
#      <font color="#000066" size="1">
#       Gust
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#000066" size="1">
#       <b>
#       </b>
#      </font>
#     </td>
#    </tr>
#    <tr align="center">
#     <td align="left" width="5%">
#      <font color="#0000CC" size="1">
#       Sky Cover (%)
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        42
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        42
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        42
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        42
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        72
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        72
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        72
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        72
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        72
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        72
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        78
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        78
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        78
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        78
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        78
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        78
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        47
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        47
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        47
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        47
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        47
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        47
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        32
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0000CC" size="1">
#       <b>
#        32
#       </b>
#      </font>
#     </td>
#    </tr>
#    <tr align="center">
#     <td align="left" width="5%">
#      <font color="#996633" size="1">
#       Precipitation Potential (%)
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        4
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        4
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        4
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        4
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        7
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        7
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        7
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        7
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        7
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        7
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        14
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        14
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        14
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        14
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        14
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        14
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        5
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        5
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        5
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
#        5
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#996633" size="1">
#       <b>
# ...
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#FF0000" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#    </tr>
#    <tr align="center">
#     <td align="left" width="5%">
#      <font color="#0099CC" size="1">
#       Snow
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#0099CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#    </tr>
#    <tr align="center">
#     <td align="left" width="5%">
#      <font color="#CC99CC" size="1">
#       Freezing Rain
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#CC99CC" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#    </tr>
#    <tr align="center">
#     <td align="left" width="5%">
#      <font color="#F06600" size="1">
#       Sleet
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#     <td align="center" width="3%">
#      <font color="#F06600" size="1">
#       <b>
#        --
#       </b>
#      </font>
#     </td>
#    </tr>
#   </table>
#   <br/>
#   <table align="center" border="0" width="650">
#    <tr>
#     <td align="center" valign="top" width="50%">
#      <img alt="Radar and Satellite (Click for larger image)" src="/images/wtf/radandsat.jpg" title="Radar and Satellite (Click for larger image)"/>
#      <br/>
#      <a href="http://radar.weather.gov/radar.php?rid=max&amp;product=N0R&amp;overlay=11101111&amp;loop=no">
#       <img alt="Link to Local Radar Data" border="0" height="130" src="http://radar.weather.gov/Thumbs/MAX_Thumb.gif" title="Link to Local Radar Data" width="130"/>
#      </a>
#      <a href="http://www.wrh.noaa.gov/satellite/?wfo=sto">
#       <img alt="Link to Satellite Data" border="0" height="130" src="http://sat.wrh.noaa.gov/satellite/4km/WR/IR4.thumbnail.jpg" title="Link to Satellite Data" width="173"/>
#      </a>
#     </td>
#     <td align="center" valign="top" width="50%">
#      <img alt="Additional Forecasts and Information" src="/images/wtf/addinfosml.jpg" title="Additional Forecasts and Information"/>
#      <br/>
#      <table border="0" cellpadding="1" cellspacing="0" width="320">
#       <tr bgcolor="#b0c4de">
#        <td align="left">
#         <a href="http://forecast.weather.gov/MapClick.php?&amp;AheadHour=12&amp;FcstType=digital&amp;textField1=40.9&amp;textField2=-121.8&amp;unit=1">
#          International System of Units
#         </a>
#        </td>
#        <td align="left">
#         <a href="http://www.crh.noaa.gov/product.php?site=NWS&amp;issuedby=sto&amp;product=AFD&amp;format=CI&amp;version=1&amp;glossary=1">
#          Forecast Discussion
#         </a>
#        </td>
#       </tr>
#       <tr bgcolor="#ffefd5">
#        <td>
#         <a href="http://forecast.weather.gov/MapClick.php?AheadHour=12&amp;FcstType=text&amp;textField1=40.9&amp;textField2=-121.8">
#          7-Day Forecast
#         </a>
#        </td>
#        <td>
#         <a href="http://forecast.weather.gov/MapClick.php?AheadHour=12&amp;FcstType=graphical&amp;textField1=40.9&amp;textField2=-121.8">
#          Hourly Weather Graph
#         </a>
#        </td>
#       </tr>
#       <tr bgcolor="#b0c4de">
#        <td align="center" colspan="2">
#        </td>
#       </tr>
#       <tr bgcolor="#ffefd5">
#        <td align="left">
#         <a href="http://www.wrh.noaa.gov/sto/roadrpts.php" target="_self">
#          Road Conditions
#         </a>
#        </td>
#        <td align="left">
#         <a href="http://www.wrh.noaa.gov/warnings.php?wfo=sto" target="_self">
#          Watches and Warnings
#         </a>
#        </td>
#       </tr>
#       <tr bgcolor="#b0c4de">
#        <td align="left">
#         <a href="http://www.wrh.noaa.gov/sto/observations.php" target="_self">
#          More Observations
#         </a>
#        </td>
#        <td align="left">
#         <a href="http://www.nws.noaa.gov/wtf/udaf/area/?site=sto" target="_self">
#          User Defined Area
#         </a>
#        </td>
#       </tr>
#      </table>
#     </td>
#    </tr>
#   </table>
#   <hr width="650"/>
#   <table align="center" width="650">
#    <tr valign="top">
#     <td align="left" class="gray">
#      <a href="mailto:w-sto.webmaster@noaa.gov">
#       Webmaster
#      </a>
#      <br/>
#      <a href="http://www.wrh.noaa.gov/sto">
#       NOAA's National Weather Service
#       <br/>
#       Sacramento, CA
#      </a>
#     </td>
#     <td align="left" class="gray">
#      <a href="http://weather.gov/disclaimer.php">
#       Disclaimer
#      </a>
#      <br/>
#      <a href="http://weather.gov/credits.php">
#       Credits
#      </a>
#      <br/>
#      <a href="http://weather.gov/glossary/">
#       Glossary
#      </a>
#     </td>
#     <td align="left" class="gray">
#      <a href="http://weather.gov/privacy.php">
#       Privacy Policy
#      </a>
#      <br/>
#      <a href="http://weather.gov/admin.php">
#       About Us
#      </a>
#      <br/>
#      <a href="http://weather.gov/careers.php">
#       Career Opportunities
#      </a>
#     </td>
#    </tr>
#   </table>
#  </body>
# </html>

# %%
Get_all = []
for ele in soup.find_all('td'):
    Get_all.append(ele.get_text())

# %%
IndexNames = ['Temp','Dew','WindChill','SurfWind','WindDir','Gust','SkyCover','PrecipPot',
             'RelHumid','Rain','Thunder','Snow','FreezeRain','Sleet']
IndexText = [u'Temperature (\xb0F)',u'Dewpoint (\xb0F)',u'Wind Chill (\xb0F)',u'Surface Wind (mph)',u'Wind Dir',
             u'Gust',u'Sky Cover (%)',u'Precipitation Potential (%)',u'Relative Humidity (%)',u'Rain',u'Thunder',
            u'Snow',u'Freezing Rain',u'Sleet']

IndexDict = dict(zip(IndexNames,IndexText))

# %%
List_of_lists = []


for uni in IndexText:
    index = Get_all.index(uni)
    List_of_lists.append(Get_all[index:(index+25)])

# %%
List_of_lists
# Out:
# [[u'Temperature (\xb0F)',
#   u'33',
#   u'33',
#   u'33',
#   u'33',
#   u'32',
#   u'32',
#   u'32',
#   u'33',
#   u'35',
#   u'38',
#   u'41',
#   u'43',
#   u'45',
#   u'45',
#   u'46',
#   u'46',
#   u'45',
#   u'44',
#   u'42',
#   u'40',
#   u'38',
#   u'37',
#   u'36',
#   u'36'],
#  [u'Dewpoint (\xb0F)',
#   u'23',
#   u'23',
#   u'24',
#   u'24',
#   u'24',
#   u'24',
#   u'24',
#   u'25',
#   u'25',
#   u'25',
#   u'25',
#   u'24',
#   u'24',
#   u'22',
#   u'22',
#   u'23',
#   u'24',
#   u'27',
#   u'29',
#   u'30',
#   u'30',
#   u'30',
#   u'30',
#   u'30'],
#  [u'Wind Chill (\xb0F)',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u''],
#  [u'Surface Wind (mph)',
#   u'7',
#   u'6',
#   u'6',
#   u'6',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'2',
#   u'2',
#   u'2',
#   u'2',
#   u'2',
#   u'2',
#   u'3',
#   u'3',
#   u'3',
#   u'3',
#   u'3',
#   u'3',
#   u'3',
#   u'3'],
#  [u'Wind Dir',
#   u'E',
#   u'E',
#   u'E',
#   u'E',
#   u'S',
#   u'S',
#   u'S',
#   u'NNE',
#   u'NNE',
#   u'NNE',
#   u'WSW',
#   u'WSW',
#   u'WSW',
#   u'WSW',
#   u'WSW',
#   u'WSW',
#   u'NNE',
#   u'NNE',
#   u'NNE',
#   u'NNE',
#   u'NNE',
#   u'NNE',
#   u'ENE',
#   u'ENE'],
#  [u'Gust',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u'',
#   u''],
#  [u'Sky Cover (%)',
#   u'42',
#   u'42',
#   u'42',
#   u'42',
#   u'72',
#   u'72',
#   u'72',
#   u'72',
#   u'72',
#   u'72',
#   u'78',
#   u'78',
#   u'78',
#   u'78',
#   u'78',
#   u'78',
#   u'47',
#   u'47',
#   u'47',
#   u'47',
#   u'47',
#   u'47',
#   u'32',
#   u'32'],
#  [u'Precipitation Potential (%)',
#   u'4',
#   u'4',
#   u'4',
#   u'4',
#   u'7',
#   u'7',
#   u'7',
#   u'7',
#   u'7',
#   u'7',
#   u'14',
#   u'14',
#   u'14',
#   u'14',
#   u'14',
#   u'14',
#   u'5',
#   u'5',
#   u'5',
#   u'5',
#   u'5',
#   u'5',
#   u'0',
#   u'0'],
#  [u'Relative Humidity (%)',
#   u'66',
#   u'67',
#   u'68',
#   u'69',
#   u'71',
#   u'72',
#   u'73',
#   u'71',
#   u'66',
#   u'60',
#   u'53',
#   u'47',
#   u'43',
#   u'40',
#   u'39',
#   u'40',
#   u'44',
#   u'51',
#   u'60',
#   u'68',
#   u'73',
#   u'77',
#   u'79',
#   u'80'],
#  [u'Rain',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--'],
#  [u'Thunder',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--'],
#  [u'Snow',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--'],
#  [u'Freezing Rain',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--'],
#  [u'Sleet',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--',
#   u'--']]

# %%
for ele in IndexNames:
    exec('%s = %v' % (ele,[]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-8a3e40e80770> in <module>()
#       1 for ele in IndexNames:
# ----> 2     exec('%s = %v' % (ele,[]))
#
# ValueError: unsupported format character 'v' (0x76) at index 6

# %%
Temperature = []
for ele in soup.find_all(color = '#FF0000'):
    Temperature.append(ele.get_text())
Temperature = Temperature[1:25]
Temperature = map(float, Temperature) #Changes the dtype of all data within Temperature to type float

# %%
DewPoint = []
for ele in soup.find_all(color = '#009900'):
    DewPoint.append(ele.get_text())
DewPoint = DewPoint[1:25]
DewPoint = map(float, DewPoint) #Changes the dtype of all data within Temperature to type float

# %%
SurfaceWind = []
for ele in soup.find_all(color = '#990099'):
    SurfaceWind.append(ele.get_text())
SurfaceWind = SurfaceWind[1:25]
SurfaceWind = map(float, SurfaceWind) #Changes the dtype of all data within Temperature to type float

# %%
WindDirStr = []
for ele in soup.find_all(color = '#666666'):
    WindDirStr.append(ele.get_text())
WindDirStr = WindDirStr[1:25]

WindDir = []
for ele in WindDirStr:
    WindDir.append(DirDict[ele])
#SurfaceWind = map(float, SurfaceWind) #Changes the dtype of all data within Temperature to type float

# %%
# Out:
# [u'weather.gov\xa0',
#  u'',
#  u'',
#  u'\xa0',
#  u'',
#  u'',
#  u'',
#  u'Home',
#  u'News',
#  u'Organization',
#  u'\xa0',
#  u'Search for:\xa0\xa0NWSAll NOAA',
#  u'\xa0',
#  u'',
#  u'\xa0Point Forecast: 7 Miles W Burney CA\xa040.89N 121.8W  (Elev. 5000 ft)',
#  u'Last Update: 2:21 am PDT Oct 2, 2015',
#  u'',
#  u'[hide menu]\xa0\xa0|\xa0\xa0Font Size: A A A\xa0\xa0\xa0',
#  u'Weather ElementsWeather/PrecipitationFire WeatherTemperature (\xb0F)Dewpoint (\xb0F)Wind Chill (\xb0F)Surface Wind\xa0\xa0ktmphkm/hm/sSky Cover (%)Precipitation Potential (%)Relative Humidity (%)RainThunderSnowFreezing RainSleetFogMixing Height\xa0\xa0x100ftx100mLightning Activity LevelTrans. Wind\xa0\xa0ktmphkm/hm/s',
#  u'Weather Elements',
#  u'Weather/Precipitation',
#  u'Fire Weather',
#  u'Temperature (\xb0F)Dewpoint (\xb0F)Wind Chill (\xb0F)Surface Wind\xa0\xa0ktmphkm/hm/sSky Cover (%)Precipitation Potential (%)Relative Humidity (%)',
#  u'RainThunderSnowFreezing RainSleetFog',
#  u'Mixing Height\xa0\xa0x100ftx100mLightning Activity LevelTrans. Wind\xa0\xa0ktmphkm/hm/s',
#  u'48-Hour Period Starting: 10am Fri, Oct 2 201511am Fri, Oct 2 201512pm Fri, Oct 2 20151pm Fri, Oct 2 20152pm Fri, Oct 2 20153pm Fri, Oct 2 20154pm Fri, Oct 2 20155pm Fri, Oct 2 20156pm Fri, Oct 2 20157pm Fri, Oct 2 20158pm Fri, Oct 2 20159pm Fri, Oct 2 201510pm Fri, Oct 2 201511pm Fri, Oct 2 201512am Sat, Oct 3 20151am Sat, Oct 3 20152am Sat, Oct 3 20153am Sat, Oct 3 20154am Sat, Oct 3 20155am Sat, Oct 3 20156am Sat, Oct 3 20157am Sat, Oct 3 20158am Sat, Oct 3 20159am Sat, Oct 3 201510am Sat, Oct 3 201511am Sat, Oct 3 201512pm Sat, Oct 3 20151pm Sat, Oct 3 20152pm Sat, Oct 3 20153pm Sat, Oct 3 20154pm Sat, Oct 3 20155pm Sat, Oct 3 20156pm Sat, Oct 3 20157pm Sat, Oct 3 20158pm Sat, Oct 3 20159pm Sat, Oct 3 201510pm Sat, Oct 3 201511pm Sat, Oct 3 201512am Sun, Oct 4 20151am Sun, Oct 4 20152am Sun, Oct 4 20153am Sun, Oct 4 20154am Sun, Oct 4 20155am Sun, Oct 4 20156am Sun, Oct 4 20157am Sun, Oct 4 20158am Sun, Oct 4 20159am Sun, Oct 4 201510am Sun, Oct 4 201511am Sun, Oct 4 201512pm Sun, Oct 4 20151pm Sun, Oct 4 20152pm Sun, Oct 4 20153pm Sun, Oct 4 20154pm Sun, Oct 4 20155pm Sun, Oct 4 20156pm Sun, Oct 4 20157pm Sun, Oct 4 20158pm Sun, Oct 4 20159pm Sun, Oct 4 201510pm Sun, Oct 4 201511pm Sun, Oct 4 201512am Mon, Oct 5 20151am Mon, Oct 5 20152am Mon, Oct 5 20153am Mon, Oct 5 20154am Mon, Oct 5 20155am Mon, Oct 5 20156am Mon, Oct 5 20157am Mon, Oct 5 20158am Mon, Oct 5 20159am Mon, Oct 5 201510am Mon, Oct 5 201511am Mon, Oct 5 201512pm Mon, Oct 5 20151pm Mon, Oct 5 20152pm Mon, Oct 5 20153pm Mon, Oct 5 20154pm Mon, Oct 5 20155pm Mon, Oct 5 20156pm Mon, Oct 5 20157pm Mon, Oct 5 20158pm Mon, Oct 5 20159pm Mon, Oct 5 201510pm Mon, Oct 5 201511pm Mon, Oct 5 201512am Tue, Oct 6 20151am Tue, Oct 6 20152am Tue, Oct 6 20153am Tue, Oct 6 20154am Tue, Oct 6 20155am Tue, Oct 6 20156am Tue, Oct 6 20157am Tue, Oct 6 20158am Tue, Oct 6 20159am Tue, Oct 6 201510am Tue, Oct 6 201511am Tue, Oct 6 201512pm Tue, Oct 6 20151pm Tue, Oct 6 20152pm Tue, Oct 6 20153pm Tue, Oct 6 20154pm Tue, Oct 6 20155pm Tue, Oct 6 20156pm Tue, Oct 6 20157pm Tue, Oct 6 20158pm Tue, Oct 6 20159pm Tue, Oct 6 2015\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0',
#  u'48-Hour Period Starting: 10am Fri, Oct 2 201511am Fri, Oct 2 201512pm Fri, Oct 2 20151pm Fri, Oct 2 20152pm Fri, Oct 2 20153pm Fri, Oct 2 20154pm Fri, Oct 2 20155pm Fri, Oct 2 20156pm Fri, Oct 2 20157pm Fri, Oct 2 20158pm Fri, Oct 2 20159pm Fri, Oct 2 201510pm Fri, Oct 2 201511pm Fri, Oct 2 201512am Sat, Oct 3 20151am Sat, Oct 3 20152am Sat, Oct 3 20153am Sat, Oct 3 20154am Sat, Oct 3 20155am Sat, Oct 3 20156am Sat, Oct 3 20157am Sat, Oct 3 20158am Sat, Oct 3 20159am Sat, Oct 3 201510am Sat, Oct 3 201511am Sat, Oct 3 201512pm Sat, Oct 3 20151pm Sat, Oct 3 20152pm Sat, Oct 3 20153pm Sat, Oct 3 20154pm Sat, Oct 3 20155pm Sat, Oct 3 20156pm Sat, Oct 3 20157pm Sat, Oct 3 20158pm Sat, Oct 3 20159pm Sat, Oct 3 201510pm Sat, Oct 3 201511pm Sat, Oct 3 201512am Sun, Oct 4 20151am Sun, Oct 4 20152am Sun, Oct 4 20153am Sun, Oct 4 20154am Sun, Oct 4 20155am Sun, Oct 4 20156am Sun, Oct 4 20157am Sun, Oct 4 20158am Sun, Oct 4 20159am Sun, Oct 4 201510am Sun, Oct 4 201511am Sun, Oct 4 201512pm Sun, Oct 4 20151pm Sun, Oct 4 20152pm Sun, Oct 4 20153pm Sun, Oct 4 20154pm Sun, Oct 4 20155pm Sun, Oct 4 20156pm Sun, Oct 4 20157pm Sun, Oct 4 20158pm Sun, Oct 4 20159pm Sun, Oct 4 201510pm Sun, Oct 4 201511pm Sun, Oct 4 201512am Mon, Oct 5 20151am Mon, Oct 5 20152am Mon, Oct 5 20153am Mon, Oct 5 20154am Mon, Oct 5 20155am Mon, Oct 5 20156am Mon, Oct 5 20157am Mon, Oct 5 20158am Mon, Oct 5 20159am Mon, Oct 5 201510am Mon, Oct 5 201511am Mon, Oct 5 201512pm Mon, Oct 5 20151pm Mon, Oct 5 20152pm Mon, Oct 5 20153pm Mon, Oct 5 20154pm Mon, Oct 5 20155pm Mon, Oct 5 20156pm Mon, Oct 5 20157pm Mon, Oct 5 20158pm Mon, Oct 5 20159pm Mon, Oct 5 201510pm Mon, Oct 5 201511pm Mon, Oct 5 201512am Tue, Oct 6 20151am Tue, Oct 6 20152am Tue, Oct 6 20153am Tue, Oct 6 20154am Tue, Oct 6 20155am Tue, Oct 6 20156am Tue, Oct 6 20157am Tue, Oct 6 20158am Tue, Oct 6 20159am Tue, Oct 6 201510am Tue, Oct 6 201511am Tue, Oct 6 201512pm Tue, Oct 6 20151pm Tue, Oct 6 20152pm Tue, Oct 6 20153pm Tue, Oct 6 20154pm Tue, Oct 6 20155pm Tue, Oct 6 20156pm Tue, Oct 6 20157pm Tue, Oct 6 20158pm Tue, Oct 6 20159pm Tue, Oct 6 2015\xa0\xa0\xa0\xa0\xa0\xa0',
#  u'\xa0\xa0',
#  u'',
#  u'Date',
#  u'10/03',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'Hour (PDT)',
#  u'00',
#  u'01',
#  u'02',
#  u'03',
#  u'04',
#  u'05',
#  u'06',
#  u'07',
#  u'08',
#  u'09',
#  u'10',
#  u'11',
#  u'12',
#  u'13',
#  u'14',
#  u'15',
#  u'16',
#  u'17',
#  u'18',
#  u'19',
#  u'20',
#  u'21',
#  u'22',
#  u'23',
#  u'Temperature (\xb0F)',
#  u'50',
#  u'48',
#  u'46',
#  u'45',
#  u'44',
#  u'44',
#  u'44',
#  u'45',
#  u'46',
#  u'47',
#  u'49',
#  u'51',
#  u'53',
#  u'55',
#  u'57',
#  u'59',
#  u'60',
#  u'61',
#  u'61',
#  u'59',
#  u'58',
#  u'55',
#  u'53',
#  u'51',
#  u'Dewpoint (\xb0F)',
#  u'35',
#  u'35',
#  u'34',
#  u'34',
#  u'33',
#  u'33',
#  u'32',
#  u'30',
#  u'27',
#  u'24',
#  u'21',
#  u'21',
#  u'22',
#  u'26',
#  u'30',
#  u'33',
#  u'37',
#  u'40',
#  u'42',
#  u'41',
#  u'41',
#  u'40',
#  u'39',
#  u'38',
#  u'Wind Chill (\xb0F)',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'Surface Wind (mph)',
#  u'13',
#  u'13',
#  u'13',
#  u'13',
#  u'13',
#  u'9',
#  u'9',
#  u'9',
#  u'9',
#  u'9',
#  u'9',
#  u'13',
#  u'13',
#  u'13',
#  u'13',
#  u'13',
#  u'13',
#  u'26',
#  u'26',
#  u'26',
#  u'26',
#  u'26',
#  u'26',
#  u'30',
#  u'Wind Dir',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'Gust',
#  u'20',
#  u'20',
#  u'20',
#  u'20',
#  u'20',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'43',
#  u'43',
#  u'43',
#  u'43',
#  u'43',
#  u'43',
#  u'48',
#  u'Sky Cover (%)',
#  u'7',
#  u'7',
#  u'7',
#  u'7',
#  u'7',
#  u'42',
#  u'42',
#  u'42',
#  u'42',
#  u'42',
#  u'42',
#  u'65',
#  u'65',
#  u'65',
#  u'65',
#  u'65',
#  u'65',
#  u'70',
#  u'70',
#  u'70',
#  u'70',
#  u'70',
#  u'70',
#  u'52',
#  u'Precipitation Potential (%)',
#  u'0',
#  u'0',
#  u'0',
#  u'0',
#  u'0',
#  u'5',
#  u'5',
#  u'5',
#  u'5',
#  u'5',
#  u'5',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'Relative Humidity (%)',
#  u'56',
#  u'60',
#  u'62',
#  u'64',
#  u'64',
#  u'65',
#  u'62',
#  u'55',
#  u'48',
#  u'40',
#  u'33',
#  u'30',
#  u'30',
#  u'32',
#  u'35',
#  u'38',
#  u'42',
#  u'46',
#  u'49',
#  u'52',
#  u'54',
#  u'57',
#  u'59',
#  u'61',
#  u'Rain',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'Thunder',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'--',
#  u'Snow',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'Freezing Rain',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'Sleet',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'',
#  u'Date',
#  u'10/04',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'Hour (PDT)',
#  u'00',
#  u'01',
#  u'02',
#  u'03',
#  u'04',
#  u'05',
#  u'06',
#  u'07',
#  u'08',
#  u'09',
#  u'10',
#  u'11',
#  u'12',
#  u'13',
#  u'14',
#  u'15',
#  u'16',
#  u'17',
#  u'18',
#  u'19',
#  u'20',
#  u'21',
#  u'22',
#  u'23',
#  u'Temperature (\xb0F)',
#  u'50',
#  u'49',
#  u'49',
#  u'49',
#  u'49',
#  u'50',
#  u'50',
#  u'51',
#  u'51',
#  u'53',
#  u'54',
#  u'56',
#  u'58',
#  u'60',
#  u'63',
#  u'65',
#  u'66',
#  u'67',
#  u'66',
#  u'64',
#  u'61',
#  u'58',
#  u'54',
#  u'50',
#  u'Dewpoint (\xb0F)',
#  u'38',
#  u'38',
#  u'39',
#  u'40',
#  u'42',
#  u'44',
#  u'44',
#  u'45',
#  u'45',
#  u'46',
#  u'47',
#  u'47',
#  u'46',
#  u'45',
#  u'45',
#  u'43',
#  u'41',
#  u'41',
#  u'40',
#  u'41',
#  u'42',
#  u'42',
#  u'42',
#  u'40',
#  u'Wind Chill (\xb0F)',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'Surface Wind (mph)',
#  u'30',
#  u'30',
#  u'30',
#  u'30',
#  u'30',
#  u'24',
#  u'24',
#  u'24',
#  u'24',
#  u'24',
#  u'24',
#  u'16',
#  u'16',
#  u'16',
#  u'16',
#  u'16',
#  u'16',
#  u'11',
#  u'11',
#  u'11',
#  u'11',
#  u'11',
#  u'11',
#  u'10',
#  u'Wind Dir',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'NE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'ENE',
#  u'E',
#  u'Gust',
#  u'48',
#  u'48',
#  u'48',
#  u'48',
#  u'48',
#  u'39',
#  u'39',
#  u'39',
#  u'39',
#  u'39',
#  u'39',
#  u'25',
#  u'25',
#  u'25',
#  u'25',
#  u'25',
#  u'25',
#  u'18',
#  u'18',
#  u'18',
#  u'18',
#  u'18',
#  u'18',
#  u'',
#  u'Sky Cover (%)',
#  u'52',
#  u'52',
#  u'52',
#  u'52',
#  u'52',
#  u'45',
#  u'45',
#  u'45',
#  u'45',
#  u'45',
#  u'45',
#  u'42',
#  u'42',
#  u'42',
#  u'42',
#  u'42',
#  u'42',
#  u'42',
#  u'42',
#  u'42',
#  u'42',
#  u'42',
#  u'42',
#  u'33',
#  u'Precipitation Potential (%)',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'21',
#  u'8',
#  u'8',
#  u'8',
#  u'8',
#  u'8',
#  u'8',
#  u'9',
#  u'9',
#  u'9',
#  u'9',
#  u'9',
#  u'9',
#  u'7',
#  u'7',
#  u'7',
#  u'7',
#  u'7',
#  u'7',
#  u'8',
#  u'Relative Humidity (%)',
#  u'64',
#  u'66',
#  u'69',
#  u'72',
#  u'78',
#  u'79',
#  u'80',
#  u'80',
#  u'80',
#  u'78',
#  u'76',
#  u'71',
#  u'65',
#  u'58',
#  u'51',
#  u'45',
#  u'40',
#  u'38',
#  u'39',
#  u'43',
#  u'49',
#  u'56',
#  u'63',
#  u'69',
#  u'Rain',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'SChc',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'Thunder',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'Snow',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'Freezing Rain',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'Sleet',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'--',
#  u'\xa0',
#  u'International System of UnitsForecast Discussion7-Day ForecastHourly Weather GraphRoad ConditionsWatches and WarningsMore ObservationsUser Defined Area',
#  u'International System of Units',
#  u'Forecast Discussion',
#  u'7-Day Forecast',
#  u'Hourly Weather Graph',
#  u'',
#  u'Road Conditions',
#  u'Watches and Warnings',
#  u'More Observations',
#  u'User Defined Area',
#  u"WebmasterNOAA's National Weather ServiceSacramento, CA",
#  u'DisclaimerCreditsGlossary',
#  u'Privacy PolicyAbout UsCareer Opportunities']

# %%
# Out:
# 79

# %%
# Out:
# [u'50',
#  u'48',
#  u'46',
#  u'45',
#  u'44',
#  u'44',
#  u'44',
#  u'45',
#  u'46',
#  u'47',
#  u'49',
#  u'51',
#  u'53',
#  u'55',
#  u'57',
#  u'59',
#  u'60',
#  u'61',
#  u'61',
#  u'59',
#  u'58',
#  u'55',
#  u'53',
#  u'51']

# %%
Get_all.index(u'Dewpoint (\xb0F)')
# Out:
# 104

# %%
def get_category_links(passed_url):
    #html = urlopen(passed_url).read()
    soup = BeautifulSoup(html, 'lxml')
    dates = soup.find_all('td', 'date')
    print BeautifulSoup.get_text()
    return dates, soup

# %%
raw_data, raw_soup = get_category_links(lurl[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-43890fe0fef4> in <module>()
# ----> 1 raw_data, raw_soup = get_category_links(lurl[0])
#
# <ipython-input-24-ea084c1c6aac> in get_category_links(section_url)
#       3     soup = BeautifulSoup(html, 'lxml')
#       4     dates = soup.find_all('td', 'date')
# ----> 5     print BeautifulSoup.get_text()
#       6     return dates, soup
#
# TypeError: unbound method get_text() must be called with BeautifulSoup instance as first argument (got nothing instead)

# %%
raw_data[0:10]
# Out:
# [<td class="date" width="3%"><font size="1"><b>10/03</b></font></td>,
#  <td class="date" width="3%"><font size="1"></font></td>,
#  <td class="date" width="3%"><font size="1"></font></td>,
#  <td class="date" width="3%"><font size="1"></font></td>,
#  <td class="date" width="3%"><font size="1"></font></td>,
#  <td class="date" width="3%"><font size="1"></font></td>,
#  <td class="date" width="3%"><font size="1"></font></td>,
#  <td class="date" width="3%"><font size="1"></font></td>,
#  <td class="date" width="3%"><font size="1"></font></td>,
#  <td class="date" width="3%"><font size="1"></font></td>]

# %%
def find_data(raw_data):
    for entry in raw_data:
        begin = entry.find('<b>')
        print begin
        end = entry.find('</b>')
        print end
    return begin, end

# %%
raw_data.find('<b>')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-262d50f92fcb> in <module>()
# ----> 1 raw_data.find('<b>')
#
# AttributeError: 'ResultSet' object has no attribute 'find'

# %%
print b
# Out:
# None

# %%
list_results = []
for b in raw_data:
    list_results.append(b)

# %%
page = requests.get('http://forecast.weather.gov/MapClick.php?lat=33.9278&lon=-116.7027&unit=0&lg=english&FcstType=digital')
tree = html.fromstring(page.text)

# %%
import pandas as pd

# %%
datetime.datetime.now().time()
# Out:
# datetime.time(15, 57, 19, 686469)

# %%
example_url = 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=33.9278&textField2=-116.7027'

# %%
example_url
# Out:
# 'http://forecast.weather.gov/MapClick.php?&AheadHour=12&FcstType=digital&textField1=33.9278&textField2=-116.7027'

# %%
# !ls
# Out:
# 3383x11622_weather.csv               gitPlayground
# AMEXrewards.pdf                      latexCheatSheet.pdf
# Commute Time.xlsx                    number of people in CML by week.xlsx
# Macintosh HD                         print_logs.pdf
# NOAA_ForecastScrape.ipynb            pylxml.pdf
# Wind_CapLoc.csv                      referenceMaterial
# gadsProject_TeXFile                  tickler

# %%
df = pd.read_csv('Wind_CapLoc.csv')

# %%
df
# Out:
#      Index                           Name  Capacity MWH    Lat    Long  \
# 0   100100        Hatchet Ridge Wind Farm         102.0  40.90 -121.80
# 1    84500             HIGH WINDS PROJECT         162.0  38.14 -121.81
# 2    92900          SHILOH I WIND PROJECT         150.0  38.12 -121.85
# 3    97300          Shiloh Wind Project 2         150.0  38.17 -121.85
# 4   113800    Solano Wind Project Phase 3         127.8  38.12 -121.77
# ..     ...                            ...           ...    ...     ...
# 61   23000               Mountain View II          22.2  33.92 -116.56
# 62  122500                        Phoenix          11.2  33.91 -116.58
# 63  112500  Ocotillo Wind Energy Facility         265.0  32.75 -116.04
# 64  124200                ESJ Wind Energy         155.1  32.56 -116.06
# 65   92600             KUMEYAAY WIND FARM          50.0  32.71 -116.34
#
#    Start Date
# 0    11/19/10
# 1    12/23/03
# 2     3/30/06
# 3     1/27/09
# 4     4/18/12
# ..        ...
# 61    9/17/01
# 62    1/26/15
# 63    7/30/13
# 64        NaN
# 65   12/21/05
#
# [66 rows x 6 columns]

# %%
pd.options.display.max_rows = 10

# %%
pd.options.display.max_columns = 15

# %%
a = 1.1234567890123456789012345678901234567890123456789012345678901

# %%
a
# Out:
# 1.1234567890123457
